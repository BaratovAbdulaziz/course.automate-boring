# %% [markdown]
# # Chapter_2 - Boolean operations

# %%
import random
starting_with = int(input(" Enter first number:"))
ending_with = int(input("Enter the ending number:"))
secret_number = random.randint(starting_with,ending_with)
if secret_number < 18:
    print(f"The number is: {secret_number}" + f" and it is less than 18")
else:
    print(f"Number is {secret_number} and that is True that it is  higher than 18")
# Out:
# The number is: 14 and it is less than 18

# %% [markdown]
# # import-----------------------> used to add new availabilities by including new functions  and modules to a project
# # print(f"")-------F-string----> allows print take information from variables

# %%
1 == 1
# true
"hello" == "hello"
# true
1 == 2
# false
"Hello" == "hello"
# False
# Out:
# False

# %% [markdown]
# # True/False ------------> boolean values that indicates weather an information or some information is correct or not
# # Always capital letters

# %% [markdown]
# - # Let's write our first program in python
# - game
# - Number gusing

# %%
import random
# making necessary Info
def sayHello():
    print('''
    ⠀⣤⡀⠀⢀⡴⠚⠁⠀⠀⠀⡠⢊⠵⡈⡆⠀⠀⠀⠈⢱⠆⠀⠀
    ⡜⡷⢱⠔⠁⠀⠀⠀⠀⠀⠊⠰⠇⣀⡇⡇⢀⠀⢀⣠⠏⠀⠀⠀
    ⣇⣧⡋⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠀⠇⠈⠙⠛⢤⡀⠀⠀⠀
    ⢘⡏⠀⠀⠀⠀⠀⠰⠊⢀⡠⢄⡀⠀⠀⠀⠀⠀⠀⠀⠙⢦⠀⠀
    ⢸⢰⠋⢢⠀⠀⠀⠀⡔⢁⣤⡀⠹⡀⠀⠀⠀⠀⠀⠀⠀⠀⢳⡀
    ⠈⡇⢰⡟⢳⡀⢀⠎⠀⡿⣄⣼⠀⠇⠀⠀⠀⠀⠠⡄⠀⠀⠀⣳
    ⠀⠰⡸⣽⣿⣈⣁⣀⠀⠙⠿⢃⡼⠲⡀⠀⠀⠀⠀⠹⡍⠉⠉⠁
    ⠀⠀⢵⠒⠋⠿⠗⠀⠉⠉⠉⡩⠀⢀⡇⠀⠀⠀⠀⠀⢧⠀⠀⠀
    ⠀⠀⠘⠢⣄⡀⠀⠀⠀⠀⣉⣠⠴⠋⠀⣀⣀⡀⠀⠀⡞⠀⠀⠀
    ⠀⠀⠀⠀⠀⠈⠉⠉⠉⠉⠀⠀⠀⠀⠀⠀⠀⠉⠑⠦⠃⠀⠀⠀''')
    print("Welcome to number gassing game")

# %%
import sys
sayHello()
no_need_random_number = random.randint(3,20)
random_number = random.randint(0,no_need_random_number)
print(f"The number you need to guess is under or EQUAL to {no_need_random_number}")
user_answer = int(input("Enter your guess here:"))
while random_number != user_answer:
    if user_answer > random_number:
        print(f"{user_answer} is higher than the number you need to guess")
        continue
    elif user_answer < random_number:
        print(f"{user_answer} is lower than the number you need to guess")
        continue
    elif user_answer == random_number:
        print('''
_____.___.                                                               .___      __      ___.    
\__  |   | ____  __ __  __  _  ______   ____      ____   ____   ____   __| _/     |__| ____\_ |__  
 /   |   |/  _ \|  |  \ \ \/ \/ /  _ \ /    \    / ___\ /  _ \ /  _ \ / __ |      |  |/  _ \| __ \ 
 \____   (  <_> )  |  /  \     (  <_> )   |  \  / /_/  >  <_> |  <_> ) /_/ |      |  (  <_> ) \_\ \
 / ______|\____/|____/    \/\_/ \____/|___|  /  \___  / \____/ \____/\____ |  /\__|  |\____/|___  /
 \/                                        \/  /_____/                    \/  \______|          \/ ''')
        print(f"you won the number is:{random_number}")
        break
    else:
        print("TypeError")
else:
    sys.exit()
# Out:
# <>:15: SyntaxWarning: invalid escape sequence '\_'
# <>:15: SyntaxWarning: invalid escape sequence '\_'
# /tmp/ipykernel_10529/3607024941.py:15: SyntaxWarning: invalid escape sequence '\_'
#   print('''
#     ⠀⣤⡀⠀⢀⡴⠚⠁⠀⠀⠀⡠⢊⠵⡈⡆⠀⠀⠀⠈⢱⠆⠀⠀
#     ⡜⡷⢱⠔⠁⠀⠀⠀⠀⠀⠊⠰⠇⣀⡇⡇⢀⠀⢀⣠⠏⠀⠀⠀
#     ⣇⣧⡋⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠀⠇⠈⠙⠛⢤⡀⠀⠀⠀
#     ⢘⡏⠀⠀⠀⠀⠀⠰⠊⢀⡠⢄⡀⠀⠀⠀⠀⠀⠀⠀⠙⢦⠀⠀
#     ⢸⢰⠋⢢⠀⠀⠀⠀⡔⢁⣤⡀⠹⡀⠀⠀⠀⠀⠀⠀⠀⠀⢳⡀
#     ⠈⡇⢰⡟⢳⡀⢀⠎⠀⡿⣄⣼⠀⠇⠀⠀⠀⠀⠠⡄⠀⠀⠀⣳
#     ⠀⠰⡸⣽⣿⣈⣁⣀⠀⠙⠿⢃⡼⠲⡀⠀⠀⠀⠀⠹⡍⠉⠉⠁
#     ⠀⠀⢵⠒⠋⠿⠗⠀⠉⠉⠉⡩⠀⢀⡇⠀⠀⠀⠀⠀⢧⠀⠀⠀
#     ⠀⠀⠘⠢⣄⡀⠀⠀⠀⠀⣉⣠⠴⠋⠀⣀⣀⡀⠀⠀⡞⠀⠀⠀
#     ⠀⠀⠀⠀⠀⠈⠉⠉⠉⠉⠀⠀⠀⠀⠀⠀⠀⠉⠑⠦⠃⠀⠀⠀
# Welcome to number gassing game
# The number you need to gass is under or EQUAL to 19
# 4 is lower than the number you need to guss
# 4 is lower than the number you need to guss
# 4 is lower than the number you need to guss
# 4 is lower than the number you need to guss
# 4 is lower than the number you need to guss
# 4 is lower than the number you need to guss
# 4 is lower than the number you need to guss
# 4 is lower than the number you need to guss
# ...

# %% [markdown]
# # problem in the code is infinite loop

# %%
import random

def sayHello():
    print('''
    ⠀⣤⡀⠀⢀⡴⠚⠁⠀⠀⠀⡠⢊⠵⡈⡆⠀⠀⠀⠈⢱⠆⠀⠀
    ⡜⡷⢱⠔⠁⠀⠀⠀⠀⠀⠊⠰⠇⣀⡇⡇⢀⠀⢀⣠⠏⠀⠀⠀
    ⣇⣧⡋⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠀⠇⠈⠙⠛⢤⡀⠀⠀⠀
    ⢘⡏⠀⠀⠀⠀⠀⠰⠊⢀⡠⢄⡀⠀⠀⠀⠀⠀⠀⠀⠙⢦⠀⠀
    ⢸⢰⠋⢢⠀⠀⠀⠀⡔⢁⣤⡀⠹⡀⠀⠀⠀⠀⠀⠀⠀⠀⢳⡀
    ⠈⡇⢰⡟⢳⡀⢀⠎⠀⡿⣄⣼⠀⠇⠀⠀⠀⠀⠠⡄⠀⠀⠀⣳
    ⠀⠰⡸⣽⣿⣈⣁⣀⠀⠙⠿⢃⡼⠲⡀⠀⠀⠀⠀⠹⡍⠉⠉⠁
    ⠀⠀⢵⠒⠋⠿⠗⠀⠉⠉⠉⡩⠀⢀⡇⠀⠀⠀⠀⠀⢧⠀⠀⠀
    ⠀⠀⠘⠢⣄⡀⠀⠀⠀⠀⣉⣠⠴⠋⠀⣀⣀⡀⠀⠀⡞⠀⠀⠀
    ⠀⠀⠀⠀⠀⠈⠉⠉⠉⠉⠀⠀⠀⠀⠀⠀⠀⠉⠑⠦⠃⠀⠀⠀''')
    print("🎉 Welcome to the Number Guessing Game!\n")

# Game logic
def guess_the_number():
    no_need_random_number = random.randint(3, 20)
    random_number = random.randint(0, no_need_random_number)
    print(f"The number you need to guess is under or EQUAL to {no_need_random_number}")
    
    while True:
        user_answer = input("Enter your guess here: ")

        # Check if input is a valid number
        if user_answer.isdigit():
            user_answer = int(user_answer)
            
            if user_answer > random_number:
                print(f"{user_answer} is higher than the number you need to guess.")
            elif user_answer < random_number:
                print(f"{user_answer} is lower than the number you need to guess.")
            else:
                print('''
_____.___.                                                               .___      __      ___.    
\\__  |   | ____  __ __  __  _  ______   ____      ____   ____   ____   __| _/     |__| ____\\_ |__  
 /   |   |/  _ \\|  |  \\ \\ \\/ \\/ /  _ \\ /    \\    / ___\\ /  _ \\ /  _ \\ / __ |      |  |/  _ \\| __ \\ 
 \\____   (  <_> )  |  /  \\     (  <_> )   |  \\  / /_/  >  <_> |  <_> ) /_/ |      |  (  <_> ) \\_\\ \\
 / ______|\\____/|____/    \\/\\_/ \\____/|___|  /  \\___  / \\____/ \\____/\\____ |  /\\__|  |\\____/|___  /
 \\/                                        \\/  /_____/                    \\/  \\______|          \\/ 
''')
                print(f"🎉 You won! The number was: {random_number}")
                break
        else:
            print("❌ Please enter a valid integer.")

# Start the game
sayHello()
guess_the_number()
# Out:
#     ⠀⣤⡀⠀⢀⡴⠚⠁⠀⠀⠀⡠⢊⠵⡈⡆⠀⠀⠀⠈⢱⠆⠀⠀
#     ⡜⡷⢱⠔⠁⠀⠀⠀⠀⠀⠊⠰⠇⣀⡇⡇⢀⠀⢀⣠⠏⠀⠀⠀
#     ⣇⣧⡋⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠀⠇⠈⠙⠛⢤⡀⠀⠀⠀
#     ⢘⡏⠀⠀⠀⠀⠀⠰⠊⢀⡠⢄⡀⠀⠀⠀⠀⠀⠀⠀⠙⢦⠀⠀
#     ⢸⢰⠋⢢⠀⠀⠀⠀⡔⢁⣤⡀⠹⡀⠀⠀⠀⠀⠀⠀⠀⠀⢳⡀
#     ⠈⡇⢰⡟⢳⡀⢀⠎⠀⡿⣄⣼⠀⠇⠀⠀⠀⠀⠠⡄⠀⠀⠀⣳
#     ⠀⠰⡸⣽⣿⣈⣁⣀⠀⠙⠿⢃⡼⠲⡀⠀⠀⠀⠀⠹⡍⠉⠉⠁
#     ⠀⠀⢵⠒⠋⠿⠗⠀⠉⠉⠉⡩⠀⢀⡇⠀⠀⠀⠀⠀⢧⠀⠀⠀
#     ⠀⠀⠘⠢⣄⡀⠀⠀⠀⠀⣉⣠⠴⠋⠀⣀⣀⡀⠀⠀⡞⠀⠀⠀
#     ⠀⠀⠀⠀⠀⠈⠉⠉⠉⠉⠀⠀⠀⠀⠀⠀⠀⠉⠑⠦⠃⠀⠀⠀
# 🎉 Welcome to the Number Guessing Game!
#
# The number you need to guess is under or EQUAL to 20
# 14 is lower than the number you need to guess.
# 16 is lower than the number you need to guess.
# 20 is higher than the number you need to guess.
# 18 is lower than the number you need to guess.
#
# _____.___.                                                               .___      __      ___.
# \__  |   | ____  __ __  __  _  ______   ____      ____   ____   ____   __| _/     |__| ____\_ |__
#  /   |   |/  _ \|  |  \ \ \/ \/ /  _ \ /    \    / ___\ /  _ \ /  _ \ / __ |      |  |/  _ \| __ \
# ...

# %% [markdown]
# # print(''' ''') mtable  lined printing (Mostly used to comment modules)
# # == / < / >/ <= / >=
# # side1 == side2 ------------------>exactly the same
# # side1 < side2---------------------> side1 is lower than side2
# # side1 > side2---------------------> side1 is higher than side2
# # side1 <= side2---------------------> side1 is lower or equal to side2
# # side1 >= side2---------------------> side1 is higher or equal to side2
# # |--------------- random module ---------------|
# # random module made  for doing random actions
# # attributes randint/choice/shuffle
# # randint ----------------------------> generating random numbers (first number , second number)
# # shuffle ----------------------------> Shakes an order of a list
# # choice -----------------------------> chooses random from a list
